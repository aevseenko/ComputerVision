# %%
import numpy as np

# %%
import cv2 as cv

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = mpimg.imread("c:/image.png")

# %%
import matplotlib as mpl

# %%
plt.imshow(img)

# %%
size = 100
width = 2

circle1 = cv.getStructuringElement(cv.MORPH_ELLIPSE, (size, size))
plt.imshow(circle1, 'gray')

# %%
circle2 = cv.getStructuringElement(cv.MORPH_ELLIPSE, (size - 2 * width, size - 2 * width))
plt.imshow(circle2, 'gray')

# %%
plt.imshow(circle1 - circle2, 'gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-af3a19c76c56> in <module>()
#       1
# ----> 2 plt.imshow(circle1 - circle2, 'gray')
#
# ValueError: operands could not be broadcast together with shapes (100,100) (96,96)
