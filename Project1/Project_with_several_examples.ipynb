# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
# %matplotlib inline
import math

# %% [markdown]
# ## Выделить и посчитать ложки и сахар

# %% [markdown]
# ### Пример 1

# %%
image = cv.imread("SpoonsAndSugars.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,150,255,cv.THRESH_BINARY)
plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 5)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
dist_transform = cv.distanceTransform(opening,cv.DIST_L2,5)

plt.subplot(),plt.imshow(dist_transform, cmap = 'gray')
plt.title('For Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
ret, sure_fg = cv.threshold(dist_transform,0.7*dist_transform.max(),255,0)
sure_fg = np.uint8(sure_fg)

plt.subplot(),plt.imshow(sure_fg, cmap = 'gray')
plt.title('Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contoursSpoons, hierarchySpoon = cv.findContours(sure_fg,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
spoonsCount = len(contoursSpoons)
contours, hierarchy = cv.findContours(opening,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (0, 0, 255), 2, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех предметов = ", len(contours))
print("Количество ложек = ", spoonsCount)
print("Количество сахара = ", len(contours) - spoonsCount)
# Out:
# Количество всех предметов =  9
# Количество ложек =  4
# Количество сахара =  5

# %% [markdown]
# ### Пример 2

# %%
image = cv.imread("SpoonsAndSugars2.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,150,255,cv.THRESH_BINARY)
plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 3)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
dist_transform = cv.distanceTransform(opening,cv.DIST_L2,5)

plt.subplot(),plt.imshow(dist_transform, cmap = 'gray')
plt.title('For Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
ret, sure_fg = cv.threshold(dist_transform,0.7*dist_transform.max(),255,0)
sure_fg = np.uint8(sure_fg)

plt.subplot(),plt.imshow(sure_fg, cmap = 'gray')
plt.title('Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contoursSpoons, hierarchySpoon = cv.findContours(sure_fg,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
spoonsCount = len(contoursSpoons)
contours, hierarchy = cv.findContours(opening,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 3, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех предметов = ", len(contours))
print("Количество ложек = ", spoonsCount)
print("Количество сахара = ", len(contours) - spoonsCount)
# Out:
# Количество всех предметов =  4
# Количество ложек =  4
# Количество сахара =  0

# %% [markdown]
# ### Пример 3

# %%
image = cv.imread("SpoonsAndSugars3.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,220,255,cv.THRESH_BINARY)
plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 3)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
dist_transform = cv.distanceTransform(opening,cv.DIST_L2,5)

plt.subplot(),plt.imshow(dist_transform, cmap = 'gray')
plt.title('For Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
ret, sure_fg = cv.threshold(dist_transform,0.7*dist_transform.max(),255,0)
sure_fg = np.uint8(sure_fg)

plt.subplot(),plt.imshow(sure_fg, cmap = 'gray')
plt.title('Spoons markers'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contoursSpoons, hierarchySpoon = cv.findContours(sure_fg,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
spoonsCount = len(contoursSpoons)
contours, hierarchy = cv.findContours(opening,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 3, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех предметов = ", len(contours))
print("Количество ложек = ", spoonsCount)
print("Количество сахара = ", len(contours) - spoonsCount)
# Out:
# Количество всех предметов =  14
# Количество ложек =  5
# Количество сахара =  9

# %% [markdown]
# ## Выделить и посчитать монеты разных диаметров

# %% [markdown]
# ### Пример 1

# %%
image = cv.imread("Coins.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,150, 255,cv.THRESH_BINARY)

plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 2)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
close = cv.morphologyEx(opening,cv.MORPH_CLOSE,kernel, iterations =2)

plt.subplot(),plt.imshow(close, cmap = 'gray')
plt.title('MORPH_CLOSE'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv.findContours(close,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 2, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех монет = ", len(contours))
# Out:
# Количество всех монет =  8

# %% [markdown]
# ### Пример 2

# %%
image = cv.imread("Coins2.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,50, 255,cv.THRESH_BINARY)

plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 1)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
close = cv.morphologyEx(opening,cv.MORPH_CLOSE,kernel, iterations =1)

plt.subplot(),plt.imshow(close, cmap = 'gray')
plt.title('MORPH_CLOSE'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv.findContours(close,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 2, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех монет = ", len(contours))
# Out:
# Количество всех монет =  11

# %% [markdown]
# ### Пример 3

# %%
image = cv.imread("Coins3.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,10, 255,cv.THRESH_BINARY)

plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 2)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
close = cv.morphologyEx(opening,cv.MORPH_CLOSE,kernel, iterations =8)

plt.subplot(),plt.imshow(close, cmap = 'gray')
plt.title('MORPH_CLOSE'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv.findContours(close,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 8, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех монет = ", len(contours))
# Out:
# Количество всех монет =  35

# %% [markdown]
# ### Пример 4

# %%
image = cv.imread("Coins4.png")

plt.subplot(),plt.imshow(image, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

plt.subplot(),plt.imshow(img, cmap = 'gray')
plt.title('Grayscale Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
histogram = np.zeros(256, np.uint16)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        histogram[img[i, j]] += 1
histogram = histogram/(img.shape[0]*img.shape[1]) 
plt.figure(figsize = (10, 10))
plt.bar(range(256), histogram, 1)
plt.show()

# %%
ret, thresh = cv.threshold(img,100, 255,cv.THRESH_BINARY)

plt.subplot(),plt.imshow(thresh, cmap = 'gray')
plt.title('Binary Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
kernel = np.ones((3,3),np.uint8)
opening = cv.morphologyEx(thresh,cv.MORPH_OPEN,kernel, iterations = 2)

plt.subplot(),plt.imshow(opening, cmap = 'gray')
plt.title('MORPH_OPEN'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
close = cv.morphologyEx(opening,cv.MORPH_CLOSE,kernel, iterations =5)

plt.subplot(),plt.imshow(close, cmap = 'gray')
plt.title('MORPH_CLOSE'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
contours, hierarchy = cv.findContours(close,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
result = cv.drawContours(image.copy(), contours, -1, (255, 0, 0), 3, cv.LINE_AA, hierarchy, 2)

plt.subplot(),plt.imshow(result, cmap = 'gray')
plt.title('result'), plt.xticks([]), plt.yticks([])
plt.show()

print("Количество всех монет = ", len(contours))
# Out:
# Количество всех монет =  6
